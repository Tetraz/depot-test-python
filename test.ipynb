# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# c'est mon premier jupiter note book

# %%
print("hello world")
# Out:
# hello world

# %%
for i in [0, 1, 2, 3]:
    print("i a pour valeur", i)
# Out:
# i a pour valeur 0
# i a pour valeur 1
# i a pour valeur 2
# i a pour valeur 3
